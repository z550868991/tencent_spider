# %%
#http://www.xicidaili.com/

# %%
import requests
import re
import json
import time
from bs4 import BeautifulSoup
from lxml import etree
from requests.exceptions import ReadTimeout,ConnectionError

# %%
def cleanString(oldString):
    newString = oldString.replace('\n', '')
    newString = newString.replace('\\', '')
    newString = newString.replace('  ', '')
    newString = newString.replace('   ', '')
    return newString

# %%
def saveTotxt(disNum, date_times, user1s, user2s, content_goods, title):
    with open('data/' + title + '.txt', 'a+', encoding='utf-8') as f:
        for i in range(date_times.__len__()):
            f.write(str(disNum) + ',')
            f.write(date_times[i] + ',')
            f.write(user1s[i] + ',')
            f.write(user2s[i] + ',')
            f.write(content_goods[i].replace(',','，') + '\n')
            disNum += 1
        f.close()
    return disNum

# %%
def is_json(myjson):
    try:
        json.loads(myjson)
    except ValueError:
        return False
    return True

# %%
def getDiscussionFromOnePage(url, headers, proxies, disNum, title):
    readTimeout = False
    readTimeout_count = 0
    while True:
        try:
            response = requests.get(url, headers=headers, timeout = 20)
            break
        except ReadTimeout:
            print('Get a timeout')
            readTimeout_count += 1
        except ConnectionError:
            print('Get a timeout')
            readTimeout_count += 1
        if readTimeout_count == 5:
            readTimeout = True
            break
            
    if readTimeout == True:
        print('Always timeout. Shiped current page')
    else:
        if response.status_code == 200 and is_json(response.text):
            jsonData = response.json()
            htmlStr = str(jsonData['data']['html'])
            htmlStr = cleanString(htmlStr)
            html = etree.HTML(htmlStr)
            html_data = html.xpath('//div[@class="list_box"]/div[@class="list_ul"]/div[@class="list_li S_line1 clearfix"]')
            date_times = []
            user1s = []
            user2s = []
            content_goods = []
            for d in html_data:
                date_time = d.xpath('./child::div[@class="list_con"]/div[@class="WB_func clearfix"]/div[@class="WB_from S_txt2"]//text()')[0]
                aNum = d.xpath('./child::div[@class="list_con"]/div[@class="WB_text"]/a').__len__()
                content_bad = d.xpath('./child::div[@class="list_con"]/div[@class="WB_text"]//text()')
                user1 = content_bad[0]
                content_good = ''
                if content_bad.__len__()<4 or aNum<2:
                    for i in range(content_bad.__len__()-1):
                        content_good += content_bad[i+1]
                    user2 = ''
                else:
                    for i in range(content_bad.__len__()-3):
                        content_good += content_bad[i+3]
                    user2 = content_bad[2].replace('@','')
                content_good = content_good.replace('：','')
                content_good = content_good.replace(':','')
                date_times.append(date_time)
                user1s.append(user1)
                user2s.append(user2)
                content_goods.append(content_good)
            return saveTotxt(disNum, date_times, user1s, user2s, content_goods, title)
        elif response.status_code == 414:
            print('Get a 414 on ContentGet')
            time.sleep(30)
            return getDiscussionFromOnePage(url, headers, proxies, disNum, title)
        elif response.status_code == 503:
            print('Get a 503 on ContentGet')
            time.sleep(3)
            return getDiscussionFromOnePage(url, headers, proxies, disNum, title)
        elif (response.status_code == 200 and is_json(response.text) == False) or response.status_code == 404:
            print('Cookies out time')
            exit()
        else:
            print(str(response.status_code))
            print('Unknow ERROR')
            exit()

# %%
def getAUrlByPage(old_url, pageNum):
    url_split = old_url.split('&')
    new_url = ''
    for i in range(url_split.__len__()):
        if url_split[i].find('page=') == -1 and i < url_split.__len__()-1:
            new_url += url_split[i] + '&'
        elif url_split[i].find('page=') == -1 and i == url_split.__len__()-1:
            new_url += url_split[i]
        else:
            new_url += 'page=' + str(pageNum) + '&'
    return new_url

# %%
def getWeiboDiscussion(url, disNum, title, currPage):
    proxies = {
        "https":"https://61.128.208.94:3128",
        "https":"https://183.129.207.73:14823",
        "https":"https://223.223.187.195:80",
        "https":"https://203.93.209.163:53281",
        "https":"https://59.37.18.243:3128"
    }
    headers = {
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
        'Accept-Encoding': 'gzip, deflate, br',
        'Accept-Language': 'zh-CN,zh;q=0.9',
        'Cache-Control': 'max-age=0',
        'Connection': 'close',
        'Cookie': 'SINAGLOBAL=4454129403737.665.1540017698992; wvr=6; wb_view_log_5485650173=1440*9001; YF-Ugrow-G0=169004153682ef91866609488943c77f; SCF=AkAGBzmnRrBsZyLGJUwLkv_HUqu2cIVaKpTGSpJa2wjbmiEvsvr-ESPlL0a6ctHSmsImUu8ZYTdZlX2_ozo9pfU.; SUB=_2A252z47oDeRhGeNK41cX9S7NzD-IHXVVvOcgrDV8PUJbmtBeLRTQkW9NSVAC9kn3nCaaE6CG1ua__mrG69wVuDK7; SUBP=0033WrSXqPxfM725Ws9jqgMF55529P9D9WhkzAEoOqAfFKxUuP63.RO75JpX5K-hUgL.Fo-X1h-cSK5pS0e2dJLoIfQLxK-L1K5L1heLxK-L1hML1h5LxKML1-zL1KnLxKBLBonLB-BLxKMLBozLB--LxKqL1KqLBo.LxKBLBonLB.2LxKML12zL1KMLxKBLBonLB-BLxKML12-L12zt; SUHB=0Jvg4GJCEcSlcz; ALF=1571631670; SSOLoginState=1540095673; YF-V5-G0=5468b83cd1a503b6427769425908497c; _s_tentry=login.sina.com.cn; UOR=,,login.sina.com.cn; Apache=3309785789590.145.1540095677557; ULV=1540095677594:2:2:1:3309785789590.145.1540095677557:1540017699000; YF-Page-G0=5c7144e56a57a456abed1d1511ad79e8',
        'Host': 'weibo.com',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.92 Safari/537.36'
    }
    pageNumFlag = False
    try:
        requests.adapters.DEFAULT_RETRIES = 5
        response = requests.get(url, headers=headers, timeout = 20)
        pageNumFlag = True
    except ReadTimeout:
        print('Failed. Get page num failed1')
    except ConnectionError:
        print('Failed. Get page num failed2')
    if pageNumFlag == True and response.status_code == 200 and is_json(response.text):
        jsonData = response.json()
        pageNum = int(jsonData['data']['page']['totalpage'])
        print(pageNum)
        for i in range(pageNum-currPage):
            url = getAUrlByPage(url, i+currPage+1)
            disNum = getDiscussionFromOnePage(url, headers, proxies, disNum, title)
            print(str(i+currPage+1) + ' page finished (Total: ' + str(pageNum) + ')')
#         countNum = int(jsonData['data']['count'])
#         countNum += disNum - 1
#         i = 0
#         while(disNum < countNum):
#             url = getAUrlByPage(url, i+currPage+1)
#             disNum = getDiscussionFromOnePage(url, headers, proxies, disNum, title)
#             print(str(disNum) + ' discussion finished (Total: ' + str(countNum) + ')')
#             i += 1
        print('Finished')
    elif pageNumFlag == True and response.status_code == 414:
        print('Get a 414 on pageNumGet')
        time.sleep(30)
        return getWeiboDiscussion(url, disNum, title, currPage)
    elif pageNumFlag == True and response.status_code == 503:
        print('Get a 503 on pageNumGet')
        time.sleep(3)
        return getWeiboDiscussion(url, disNum, title, currPage)
    elif (response.status_code == 200 and is_json(response.text) == False) or response.status_code == 404:
        print('Cookies out time')
        exit()
    else:
        print(str(response.status_code))
        print('Unknow ERROR')
        exit()
    return disNum

# %%
title = '联璧金融爆雷牵出京东0元购黑幕'
disNum = 10366
currPage = 0
url = 'https://weibo.com/aj/v6/comment/big?ajwvr=6&id=4294048775215512&root_comment_max_id=370003002272735&root_comment_max_id_type=&root_comment_ext_param=&page=1&filter=all'
disNum = getWeiboDiscussion(url, disNum, title, currPage)
# Out:
# 504
# 1 page finished (Total: 504)
# 2 page finished (Total: 504)
# 3 page finished (Total: 504)
# 4 page finished (Total: 504)
# 5 page finished (Total: 504)
# 6 page finished (Total: 504)
# 7 page finished (Total: 504)
# 8 page finished (Total: 504)
# 9 page finished (Total: 504)
# 10 page finished (Total: 504)
# 11 page finished (Total: 504)
# 12 page finished (Total: 504)
# 13 page finished (Total: 504)
# 14 page finished (Total: 504)
# 15 page finished (Total: 504)
# 16 page finished (Total: 504)
# 17 page finished (Total: 504)
# 18 page finished (Total: 504)
# 19 page finished (Total: 504)
# 20 page finished (Total: 504)
# 21 page finished (Total: 504)
# 22 page finished (Total: 504)
# 23 page finished (Total: 504)
# 24 page finished (Total: 504)
# 25 page finished (Total: 504)
# 26 page finished (Total: 504)
# 27 page finished (Total: 504)
# 28 page finished (Total: 504)
# 29 page finished (Total: 504)
# 30 page finished (Total: 504)
# 31 page finished (Total: 504)
# 32 page finished (Total: 504)
# 33 page finished (Total: 504)
# 34 page finished (Total: 504)
# 35 page finished (Total: 504)
# 36 page finished (Total: 504)
# 37 page finished (Total: 504)
# 38 page finished (Total: 504)
# 39 page finished (Total: 504)
# 40 page finished (Total: 504)
# 41 page finished (Total: 504)
# 42 page finished (Total: 504)
# 43 page finished (Total: 504)
# 44 page finished (Total: 504)
# 45 page finished (Total: 504)
# 46 page finished (Total: 504)
# 47 page finished (Total: 504)
# 48 page finished (Total: 504)
# 49 page finished (Total: 504)
# 50 page finished (Total: 504)
# 51 page finished (Total: 504)
# 52 page finished (Total: 504)
# 53 page finished (Total: 504)
# 54 page finished (Total: 504)
# 55 page finished (Total: 504)
# 56 page finished (Total: 504)
# 57 page finished (Total: 504)
# 58 page finished (Total: 504)
# 59 page finished (Total: 504)
# 60 page finished (Total: 504)
# 61 page finished (Total: 504)
# 62 page finished (Total: 504)
# 63 page finished (Total: 504)
# 64 page finished (Total: 504)
# 65 page finished (Total: 504)
# 66 page finished (Total: 504)
# 67 page finished (Total: 504)
# 68 page finished (Total: 504)
# 69 page finished (Total: 504)
# 70 page finished (Total: 504)
# 71 page finished (Total: 504)
# 72 page finished (Total: 504)
# 73 page finished (Total: 504)
# 74 page finished (Total: 504)
# 75 page finished (Total: 504)
# 76 page finished (Total: 504)
# 77 page finished (Total: 504)
# 78 page finished (Total: 504)
# 79 page finished (Total: 504)
# 80 page finished (Total: 504)
# 81 page finished (Total: 504)
# 82 page finished (Total: 504)
# 83 page finished (Total: 504)
# 84 page finished (Total: 504)
# 85 page finished (Total: 504)
# 86 page finished (Total: 504)
# 87 page finished (Total: 504)
# 88 page finished (Total: 504)
# 89 page finished (Total: 504)
# 90 page finished (Total: 504)
# 91 page finished (Total: 504)
# 92 page finished (Total: 504)
# 93 page finished (Total: 504)
# 94 page finished (Total: 504)
# 95 page finished (Total: 504)
# 96 page finished (Total: 504)
# 97 page finished (Total: 504)
# 98 page finished (Total: 504)
# 99 page finished (Total: 504)
# 100 page finished (Total: 504)
# 101 page finished (Total: 504)
# 102 page finished (Total: 504)
# 103 page finished (Total: 504)
# 104 page finished (Total: 504)
# 105 page finished (Total: 504)
# 106 page finished (Total: 504)
# 107 page finished (Total: 504)
# 108 page finished (Total: 504)
# 109 page finished (Total: 504)
# 110 page finished (Total: 504)
# 111 page finished (Total: 504)
# 112 page finished (Total: 504)
# 113 page finished (Total: 504)
# 114 page finished (Total: 504)
# 115 page finished (Total: 504)
# 116 page finished (Total: 504)
# 117 page finished (Total: 504)
# 118 page finished (Total: 504)
# 119 page finished (Total: 504)
# 120 page finished (Total: 504)
# 121 page finished (Total: 504)
# 122 page finished (Total: 504)
# 123 page finished (Total: 504)
# 124 page finished (Total: 504)
# 125 page finished (Total: 504)
# 126 page finished (Total: 504)
# 127 page finished (Total: 504)
# 128 page finished (Total: 504)
# 129 page finished (Total: 504)
# 130 page finished (Total: 504)
# 131 page finished (Total: 504)
# 132 page finished (Total: 504)
# 133 page finished (Total: 504)
# 134 page finished (Total: 504)
# 135 page finished (Total: 504)
# 136 page finished (Total: 504)
# 137 page finished (Total: 504)
# 138 page finished (Total: 504)
# 139 page finished (Total: 504)
# 140 page finished (Total: 504)
# 141 page finished (Total: 504)
# 142 page finished (Total: 504)
# 143 page finished (Total: 504)
# 144 page finished (Total: 504)
# 145 page finished (Total: 504)
# 146 page finished (Total: 504)
# 147 page finished (Total: 504)
# 148 page finished (Total: 504)
# 149 page finished (Total: 504)
# 150 page finished (Total: 504)
# 151 page finished (Total: 504)
# 152 page finished (Total: 504)
# 153 page finished (Total: 504)
# 154 page finished (Total: 504)
# 155 page finished (Total: 504)
# 156 page finished (Total: 504)
# 157 page finished (Total: 504)
# 158 page finished (Total: 504)
# 159 page finished (Total: 504)
# 160 page finished (Total: 504)
# 161 page finished (Total: 504)
# 162 page finished (Total: 504)
# 163 page finished (Total: 504)
# 164 page finished (Total: 504)
# 165 page finished (Total: 504)
# 166 page finished (Total: 504)
# 167 page finished (Total: 504)
# 168 page finished (Total: 504)
# 169 page finished (Total: 504)
# 170 page finished (Total: 504)
# 171 page finished (Total: 504)
# 172 page finished (Total: 504)
# 173 page finished (Total: 504)
# 174 page finished (Total: 504)
# 175 page finished (Total: 504)
# 176 page finished (Total: 504)
# 177 page finished (Total: 504)
# 178 page finished (Total: 504)
# 179 page finished (Total: 504)
# 180 page finished (Total: 504)
# 181 page finished (Total: 504)
# 182 page finished (Total: 504)
# 183 page finished (Total: 504)
# 184 page finished (Total: 504)
# 185 page finished (Total: 504)
# 186 page finished (Total: 504)
# 187 page finished (Total: 504)
# 188 page finished (Total: 504)
# 189 page finished (Total: 504)
# 190 page finished (Total: 504)
# 191 page finished (Total: 504)
# 192 page finished (Total: 504)
# 193 page finished (Total: 504)
# 194 page finished (Total: 504)
# 195 page finished (Total: 504)
# 196 page finished (Total: 504)
# 197 page finished (Total: 504)
# 198 page finished (Total: 504)
# 199 page finished (Total: 504)
# 200 page finished (Total: 504)
# 201 page finished (Total: 504)
# 202 page finished (Total: 504)
# 203 page finished (Total: 504)
# 204 page finished (Total: 504)
# 205 page finished (Total: 504)
# 206 page finished (Total: 504)
# 207 page finished (Total: 504)
# 208 page finished (Total: 504)
# 209 page finished (Total: 504)
# 210 page finished (Total: 504)
# 211 page finished (Total: 504)
# 212 page finished (Total: 504)
# 213 page finished (Total: 504)
# 214 page finished (Total: 504)
# 215 page finished (Total: 504)
# 216 page finished (Total: 504)
# 217 page finished (Total: 504)
# 218 page finished (Total: 504)
# 219 page finished (Total: 504)
# 220 page finished (Total: 504)
# 221 page finished (Total: 504)
# 222 page finished (Total: 504)
# 223 page finished (Total: 504)
# 224 page finished (Total: 504)
# 225 page finished (Total: 504)
# 226 page finished (Total: 504)
# 227 page finished (Total: 504)
# 228 page finished (Total: 504)
# 229 page finished (Total: 504)
# 230 page finished (Total: 504)
# 231 page finished (Total: 504)
# 232 page finished (Total: 504)
# 233 page finished (Total: 504)
# 234 page finished (Total: 504)
# 235 page finished (Total: 504)
# 236 page finished (Total: 504)
# 237 page finished (Total: 504)
# 238 page finished (Total: 504)
# 239 page finished (Total: 504)
# 240 page finished (Total: 504)
# 241 page finished (Total: 504)
# 242 page finished (Total: 504)
# Get a 414 on ContentGet
# Get a 414 on ContentGet
# Get a 414 on ContentGet
# Get a 414 on ContentGet
# Get a 414 on ContentGet
# Get a 414 on ContentGet
# 243 page finished (Total: 504)
# 244 page finished (Total: 504)
# 245 page finished (Total: 504)
# 246 page finished (Total: 504)
# 247 page finished (Total: 504)
# 248 page finished (Total: 504)
# 249 page finished (Total: 504)
# 250 page finished (Total: 504)
# 251 page finished (Total: 504)
# 252 page finished (Total: 504)
# 253 page finished (Total: 504)
# 254 page finished (Total: 504)
# 255 page finished (Total: 504)
# 256 page finished (Total: 504)
# 257 page finished (Total: 504)
# 258 page finished (Total: 504)
# 259 page finished (Total: 504)
# 260 page finished (Total: 504)
# 261 page finished (Total: 504)
# 262 page finished (Total: 504)
# 263 page finished (Total: 504)
# 264 page finished (Total: 504)
# 265 page finished (Total: 504)
# 266 page finished (Total: 504)
# 267 page finished (Total: 504)
# 268 page finished (Total: 504)
# 269 page finished (Total: 504)
# 270 page finished (Total: 504)
# 271 page finished (Total: 504)
# 272 page finished (Total: 504)
# 273 page finished (Total: 504)
# 274 page finished (Total: 504)
# 275 page finished (Total: 504)
# 276 page finished (Total: 504)
# 277 page finished (Total: 504)
# 278 page finished (Total: 504)
# 279 page finished (Total: 504)
# 280 page finished (Total: 504)
# 281 page finished (Total: 504)
# 282 page finished (Total: 504)
# 283 page finished (Total: 504)
# 284 page finished (Total: 504)
# 285 page finished (Total: 504)
# 286 page finished (Total: 504)
# 287 page finished (Total: 504)
# 288 page finished (Total: 504)
# 289 page finished (Total: 504)
# 290 page finished (Total: 504)
# 291 page finished (Total: 504)
# 292 page finished (Total: 504)
# 293 page finished (Total: 504)
# 294 page finished (Total: 504)
# 295 page finished (Total: 504)
# 296 page finished (Total: 504)
# 297 page finished (Total: 504)
# 298 page finished (Total: 504)
# 299 page finished (Total: 504)
# 300 page finished (Total: 504)
# 301 page finished (Total: 504)
# 302 page finished (Total: 504)
# 303 page finished (Total: 504)
# 304 page finished (Total: 504)
# 305 page finished (Total: 504)
# 306 page finished (Total: 504)
# 307 page finished (Total: 504)
# 308 page finished (Total: 504)
# 309 page finished (Total: 504)
# 310 page finished (Total: 504)
# 311 page finished (Total: 504)
# 312 page finished (Total: 504)
# 313 page finished (Total: 504)
# 314 page finished (Total: 504)
# 315 page finished (Total: 504)
# 316 page finished (Total: 504)
# 317 page finished (Total: 504)
# 318 page finished (Total: 504)
# 319 page finished (Total: 504)
# 320 page finished (Total: 504)
# 321 page finished (Total: 504)
# 322 page finished (Total: 504)
# 323 page finished (Total: 504)
# 324 page finished (Total: 504)
# 325 page finished (Total: 504)
# 326 page finished (Total: 504)
# 327 page finished (Total: 504)
# 328 page finished (Total: 504)
# 329 page finished (Total: 504)
# 330 page finished (Total: 504)
# 331 page finished (Total: 504)
# 332 page finished (Total: 504)
# 333 page finished (Total: 504)
# 334 page finished (Total: 504)
# 335 page finished (Total: 504)
# 336 page finished (Total: 504)
# 337 page finished (Total: 504)
# 338 page finished (Total: 504)
# 339 page finished (Total: 504)
# 340 page finished (Total: 504)
# 341 page finished (Total: 504)
# 342 page finished (Total: 504)
# 343 page finished (Total: 504)
# 344 page finished (Total: 504)
# 345 page finished (Total: 504)
# 346 page finished (Total: 504)
# 347 page finished (Total: 504)
# 348 page finished (Total: 504)
# 349 page finished (Total: 504)
# 350 page finished (Total: 504)
# 351 page finished (Total: 504)
# 352 page finished (Total: 504)
# 353 page finished (Total: 504)
# 354 page finished (Total: 504)
# 355 page finished (Total: 504)
# 356 page finished (Total: 504)
# 357 page finished (Total: 504)
# 358 page finished (Total: 504)
# 359 page finished (Total: 504)
# 360 page finished (Total: 504)
# 361 page finished (Total: 504)
# 362 page finished (Total: 504)
# 363 page finished (Total: 504)
# 364 page finished (Total: 504)
# 365 page finished (Total: 504)
# 366 page finished (Total: 504)
# 367 page finished (Total: 504)
# 368 page finished (Total: 504)
# 369 page finished (Total: 504)
# 370 page finished (Total: 504)
# 371 page finished (Total: 504)
# 372 page finished (Total: 504)
# 373 page finished (Total: 504)
# 374 page finished (Total: 504)
# 375 page finished (Total: 504)
# 376 page finished (Total: 504)
# 377 page finished (Total: 504)
# 378 page finished (Total: 504)
# 379 page finished (Total: 504)
# 380 page finished (Total: 504)
# 381 page finished (Total: 504)
# 382 page finished (Total: 504)
# 383 page finished (Total: 504)
# 384 page finished (Total: 504)
# 385 page finished (Total: 504)
# 386 page finished (Total: 504)
# 387 page finished (Total: 504)
# 388 page finished (Total: 504)
# 389 page finished (Total: 504)
# 390 page finished (Total: 504)
# 391 page finished (Total: 504)
# 392 page finished (Total: 504)
# 393 page finished (Total: 504)
# 394 page finished (Total: 504)
# 395 page finished (Total: 504)
# 396 page finished (Total: 504)
# 397 page finished (Total: 504)
# 398 page finished (Total: 504)
# 399 page finished (Total: 504)
# 400 page finished (Total: 504)
# 401 page finished (Total: 504)
# 402 page finished (Total: 504)
# 403 page finished (Total: 504)
# 404 page finished (Total: 504)
# 405 page finished (Total: 504)
# 406 page finished (Total: 504)
# 407 page finished (Total: 504)
# 408 page finished (Total: 504)
# 409 page finished (Total: 504)
# 410 page finished (Total: 504)
# 411 page finished (Total: 504)
# 412 page finished (Total: 504)
# 413 page finished (Total: 504)
# 414 page finished (Total: 504)
# 415 page finished (Total: 504)
# 416 page finished (Total: 504)
# 417 page finished (Total: 504)
# 418 page finished (Total: 504)
# 419 page finished (Total: 504)
# 420 page finished (Total: 504)
# 421 page finished (Total: 504)
# 422 page finished (Total: 504)
# 423 page finished (Total: 504)
# 424 page finished (Total: 504)
# 425 page finished (Total: 504)
# 426 page finished (Total: 504)
# 427 page finished (Total: 504)
# 428 page finished (Total: 504)
# 429 page finished (Total: 504)
# 430 page finished (Total: 504)
# 431 page finished (Total: 504)
# 432 page finished (Total: 504)
# 433 page finished (Total: 504)
# 434 page finished (Total: 504)
# 435 page finished (Total: 504)
# 436 page finished (Total: 504)
# 437 page finished (Total: 504)
# 438 page finished (Total: 504)
# 439 page finished (Total: 504)
# 440 page finished (Total: 504)
# 441 page finished (Total: 504)
# 442 page finished (Total: 504)
# 443 page finished (Total: 504)
# 444 page finished (Total: 504)
# 445 page finished (Total: 504)
# 446 page finished (Total: 504)
# 447 page finished (Total: 504)
# 448 page finished (Total: 504)
# 449 page finished (Total: 504)
# 450 page finished (Total: 504)
# 451 page finished (Total: 504)
# 452 page finished (Total: 504)
# 453 page finished (Total: 504)
# 454 page finished (Total: 504)
# 455 page finished (Total: 504)
# 456 page finished (Total: 504)
# 457 page finished (Total: 504)
# 458 page finished (Total: 504)
# 459 page finished (Total: 504)
# 460 page finished (Total: 504)
# 461 page finished (Total: 504)
# 462 page finished (Total: 504)
# 463 page finished (Total: 504)
# 464 page finished (Total: 504)
# 465 page finished (Total: 504)
# 466 page finished (Total: 504)
# 467 page finished (Total: 504)
# 468 page finished (Total: 504)
# 469 page finished (Total: 504)
# 470 page finished (Total: 504)
# 471 page finished (Total: 504)
# 472 page finished (Total: 504)
# 473 page finished (Total: 504)
# 474 page finished (Total: 504)
# 475 page finished (Total: 504)
# 476 page finished (Total: 504)
# 477 page finished (Total: 504)
# 478 page finished (Total: 504)
# 479 page finished (Total: 504)
# 480 page finished (Total: 504)
# 481 page finished (Total: 504)
# 482 page finished (Total: 504)
# 483 page finished (Total: 504)
# 484 page finished (Total: 504)
# 485 page finished (Total: 504)
# 486 page finished (Total: 504)
# 487 page finished (Total: 504)
# 488 page finished (Total: 504)
# 489 page finished (Total: 504)
# 490 page finished (Total: 504)
# 491 page finished (Total: 504)
# 492 page finished (Total: 504)
# 493 page finished (Total: 504)
# 494 page finished (Total: 504)
# 495 page finished (Total: 504)
# 496 page finished (Total: 504)
# 497 page finished (Total: 504)
# 498 page finished (Total: 504)
# 499 page finished (Total: 504)
# 500 page finished (Total: 504)
# 501 page finished (Total: 504)
# 502 page finished (Total: 504)
# 503 page finished (Total: 504)
# 504 page finished (Total: 504)
# Finished
